# %% [markdown]
# <a href="https://colab.research.google.com/github/Smarth2005/Hugging-Face-Projects/blob/main/Sentiment%20Analysis%20using%20Hugging%20Face.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Sentiment Analysis using Hugging Face

# %%
# !pip install transformers

# %%
# !pip install torch
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 113.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 93.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 61.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 88.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from transformers import pipeline

# %%
sentiment_analyzer = pipeline("sentiment-analysis") # default model : distilbert-base-uncased-finetuned-sst-2-english
                                                    # Binary Sentiment Classification (Positive / Negative)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# Device set to use cuda:0

# %%
texts=[
    "I love cricket!",
    "I hate when Virat Kohli misses a century.",
    "This restaurant has the best food I've ever tasted.",
    "I absolutely love this product, it exceeded all my expectations!",
    "I am disappointed, the product broke within a week.",
    "I regret buying this, it doesn't work as advertised",
    "I have a meeting scheduled for 3 PM tomorrow.",
    "It rained yesterday, and today it's sunny.",
    "I like the taste of the coffee, though it's a bit expensive.",
    "The phone's camera is amazing, but the battery drains too quickly.",
    "The college fest was so much fun, everyone enjoyed the cultural night.",
    "The Wi-Fi in the hostel never works when I need it the most.",
    "Sessionals are so tiring, they drain all the energy before the main exams.",
    "Her smile feels like the sunshine on the darkest day."
]

results = sentiment_analyzer(texts)

for text,result in zip(texts,results):
  print(f"Text: {text}")
  print(f"Predicted Sentiment: {result['label']}, score={result['score']:.2f}")
  print()
# Out:
# Text: I love cricket!
# Predicted Sentiment: POSITIVE, score=1.00
#
# Text: I hate when Virat Kohli misses a century.
# Predicted Sentiment: NEGATIVE, score=1.00
#
# Text: This restaurant has the best food I've ever tasted.
# Predicted Sentiment: POSITIVE, score=1.00
#
# Text: I absolutely love this product, it exceeded all my expectations!
# Predicted Sentiment: POSITIVE, score=1.00
#
# Text: I am disappointed, the product broke within a week.
# Predicted Sentiment: NEGATIVE, score=1.00
#
# Text: I regret buying this, it doesn't work as advertised
# Predicted Sentiment: NEGATIVE, score=1.00
#
# Text: I have a meeting scheduled for 3 PM tomorrow.
# Predicted Sentiment: POSITIVE, score=0.94
#
# Text: It rained yesterday, and today it's sunny.
# Predicted Sentiment: POSITIVE, score=1.00
#
# Text: I like the taste of the coffee, though it's a bit expensive.
# Predicted Sentiment: POSITIVE, score=0.99
#
# Text: The phone's camera is amazing, but the battery drains too quickly.
# ...

# %%
# Three-Class Sentiment (Positive / Neutral / Negative)
model2 = pipeline("sentiment-analysis", model="cardiffnlp/twitter-roberta-base-sentiment-latest")

results = model2(texts)

for text,result in zip(texts,results):
  print(f"Text: {text}")
  print(f"Predicted Sentiment: {result['label']}, score={result['score']:.2f}")
  print()
# Out:
# config.json:   0%|          | 0.00/929 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/501M [00:00<?, ?B/s]
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# model.safetensors:   0%|          | 0.00/501M [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# ...

# %%
# Aspect-Based Sentiment Analysis (ABSA)
model3 = pipeline("sentiment-analysis", model="yangheng/deberta-v3-base-absa-v1.1")

results = model3(texts)

for text,result in zip(texts,results):
  print(f"Text: {text}")
  print(f"Predicted Sentiment: {result['label']}, score={result['score']:.2f}")
  print()
# Out:
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/738M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/372 [00:00<?, ?B/s]
# spm.model:   0%|          | 0.00/2.46M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/18.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/156 [00:00<?, ?B/s]
# /usr/local/lib/python3.11/dist-packages/transformers/convert_slow_tokenizer.py:564: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(
# Device set to use cuda:0
# Text: I love cricket!
# Predicted Sentiment: Positive, score=0.53
#
# ...
